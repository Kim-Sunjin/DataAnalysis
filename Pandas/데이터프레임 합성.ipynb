# %% [markdown]
# # 데이터프레임 합성

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# inner join
pd.merge(df1,df2, how='inner')
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
pd.merge(df1,df2,how='left')
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
pd.merge(df1,df2,how='right')
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
pd.merge(df1,df2,how='outer')
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %%
df1 = pd.DataFrame({
    '품종': ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이': [1.4, 1.3, 1.5, 1.3]},
    columns=['품종', '꽃잎길이'])
df1
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
df2 = pd.DataFrame({
    '품종': ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비': [0.4, 0.3, 0.5, 0.3]},
    columns=['품종', '꽃잎너비'])
df2
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
pd.merge(df1,df2)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %% [markdown]
# select * from tabel1
#         where 조건
#         Join table2 on 조인 조건
#         ORDER BY field []
#         LIMIT 갯수 OFFSET n
#         GROUP BY
#         HAVING 그룹핑 조건

# %%
df1 = pd.DataFrame({
    '고객명': ['춘향', '춘향', '몽룡'],
    '날짜': ['2018-01-01', '2018-01-02', '2018-01-01'],
    '데이터': ['20000', '30000', '100000']})
df1
# Out:
#   고객명          날짜     데이터
# 0  춘향  2018-01-01   20000
# 1  춘향  2018-01-02   30000
# 2  몽룡  2018-01-01  100000

# %%
df2 = pd.DataFrame({
    '고객명': ['춘향', '몽룡'],
    '데이터': ['여자', '남자']})
df2
# Out:
#   고객명 데이터
# 0  춘향  여자
# 1  몽룡  남자

# %%
pd.merge(df1,df2, on='고객명')
# Out:
#   고객명          날짜   데이터_x 데이터_y
# 0  춘향  2018-01-01   20000    여자
# 1  춘향  2018-01-02   30000    여자
# 2  몽룡  2018-01-01  100000    남자

# %%
df1 = pd.DataFrame({
    '이름': ['영희', '철수', '철수'],
    '성적': [1, 2, 3]})
df1
# Out:
#    이름  성적
# 0  영희   1
# 1  철수   2
# 2  철수   3

# %%
df2 = pd.DataFrame({
    '성명': ['영희', '영희', '철수'],
    '성적2': [4, 5, 6]})
df2
# Out:
#    성명  성적2
# 0  영희    4
# 1  영희    5
# 2  철수    6

# %%
pd.merge(df1, df2, left_on='이름', right_on="성명")
# Out:
#    이름  성적  성명  성적2
# 0  영희   1  영희    4
# 1  영희   1  영희    5
# 2  철수   2  철수    6
# 3  철수   3  철수    6

# %%
df1 = pd.DataFrame({
    '도시': ['서울', '서울', '서울', '부산', '부산'],
    '연도': [2000, 2005, 2010, 2000, 2005],
    '인구': [9853972, 9762546, 9631482, 3655437, 3512547]})
df1
# Out:
#    도시    연도       인구
# 0  서울  2000  9853972
# 1  서울  2005  9762546
# 2  서울  2010  9631482
# 3  부산  2000  3655437
# 4  부산  2005  3512547

# %%
df2 = pd.DataFrame(
    np.arange(12).reshape((6, 2)),
    index=[['부산', '부산', '서울', '서울', '서울', '서울'],
           [2000, 2005, 2000, 2005, 2010, 2015]],
    columns=['데이터1', '데이터2'])
df2
# Out:
#          데이터1  데이터2
# 부산 2000     0     1
#    2005     2     3
# 서울 2000     4     5
#    2005     6     7
#    2010     8     9
#    2015    10    11

# %%
pd.merge(df1, df2, left_on=['도시', '연도'], right_index=True)
# Out:
#    도시    연도       인구  데이터1  데이터2
# 0  서울  2000  9853972     4     5
# 1  서울  2005  9762546     6     7
# 2  서울  2010  9631482     8     9
# 3  부산  2000  3655437     0     1
# 4  부산  2005  3512547     2     3

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1.set_index('고객번호', inplace=True)
df1
# Out:
#        이름
# 고객번호
# 1001   둘리
# 1002  도우너
# 1003   또치
# 1004   길동
# 1005   희동
# 1006  마이콜
# 1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2.set_index('고객번호',inplace=True)
df2
# Out:
#           금액
# 고객번호
# 1001   10000
# 1001   20000
# 1005   15000
# 1006    5000
# 1008  100000
# 1001   30000

# %%
df1.join(df2, how='outer') # 키값이 같아야 하기에 set_index로 인덱스로 키값 통일
# Out:
#        이름        금액
# 고객번호
# 1001   둘리   10000.0
# 1001   둘리   20000.0
# 1001   둘리   30000.0
# 1002  도우너       NaN
# 1003   또치       NaN
# 1004   길동       NaN
# 1005   희동   15000.0
# 1006  마이콜    5000.0
# 1007   영희       NaN
# 1008  NaN  100000.0

# %% [markdown]
# ## concat 함수

# %%
s1= pd.Series([0,1],index=['A','B'])
s2 = pd.Series([2, 3, 4], index=['A', 'B', 'C'])

# %%
pd.concat([s1, s2])
# Out:
# A    0
# B    1
# A    2
# B    3
# C    4
# dtype: int64

# %%
df1 = pd.DataFrame(
    np.arange(6).reshape(3, 2),
    index=['a', 'b', 'c'],
    columns=['데이터1', '데이터2'])
df1
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5

# %%
df2 = pd.DataFrame(
    5 + np.arange(4).reshape(2, 2),
    index=['a', 'c'],
    columns=['데이터3', '데이터4'])
df2
# Out:
#    데이터3  데이터4
# a     5     6
# c     7     8

# %%
pd.concat([df1,df2], axis=1)
# Out:
#    데이터1  데이터2  데이터3  데이터4
# a     0     1   5.0   6.0
# b     2     3   NaN   NaN
# c     4     5   7.0   8.0

# %% [markdown]
# # 연습문제

# %%
df1 = pd.DataFrame(np.random.randint(100,1000,size=(6,2)),columns=['매출','비용'],index=['1월','2월','3월','4월','5월','6월'])
df1['이익'] = df1.매출 - df1.비용
df1
# Out:
#      매출   비용   이익
# 1월  564  359  205
# 2월  585  626  -41
# 3월  227  713 -486
# 4월  581  936 -355
# 5월  378  755 -377
# 6월  375  548 -173

# %%
df2 = pd.DataFrame(np.random.randint(100,1000,size=(6,2)),columns=['매출','비용'],index=['7월','8월','9월','10월','11월','12월'])
df2['이익'] = df2.매출 - df2.비용
df2
# Out:
#       매출   비용   이익
# 7월   950  919   31
# 8월   506  741 -235
# 9월   395  513 -118
# 10월  494  261  233
# 11월  734  817  -83
# 12월  276  479 -203

# %%
df = pd.concat([df1,df2],axis=0)

# %%
df.sum()
# Out:
# 매출    6065
# 비용    7667
# 이익   -1602
# dtype: int64

# %%
tdf = pd.DataFrame(df.sum()).T
tdf
# Out:
#      매출    비용    이익
# 0  6065  7667 -1602

# %%
df = pd.concat([df,tdf])
df
# Out:
#        매출    비용    이익
# 1월    564   359   205
# 2월    585   626   -41
# 3월    227   713  -486
# 4월    581   936  -355
# 5월    378   755  -377
# 6월    375   548  -173
# 7월    950   919    31
# 8월    506   741  -235
# 9월    395   513  -118
# 10월   494   261   233
# 11월   734   817   -83
# 12월   276   479  -203
# 0    6065  7667 -1602
